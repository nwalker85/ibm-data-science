# %%
import pandas as pd

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)

# %%
df.plot()

# WHAT THE FUCK I DIDN'T KNOW THIS WAS A THING
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='scatter', x='price', y='highway-mpg')
# Out:
# <AxesSubplot:xlabel='price', ylabel='highway-mpg'>

# %%
import matplotlib.pyplot as plt

# %%
ax = plt.gca()
df.plot(kind='scatter', x='price', y='highway-mpg', color='blue', ax=ax)
df.plot(kind='scatter', x='price', y='engine-size', color='red', ax=ax)
plt.show()
